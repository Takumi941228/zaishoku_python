# %% [markdown]
# 演習プログラム１

# %%
# Numpyモジュールをnpという名前でimport
import numpy as np

# グラフ描画ライブラリ matplotlibのpyplotを plt という名前でimport
import matplotlib.pyplot as plt

#Jupyter Notebookの場合は、描画グラフをブラウザ内に表示するために inline指定
# %matplotlib inline

# %%
# x軸のリストとy軸のリストに数値を格納
x = [0, 1, 2, 3, 4, 5]
y = [0, 2, 4, 6, 8, 10]

# %%
# グラフ描画
plt.plot(x, y)

# %%
# x軸のリストとy軸のリストに数値を格納
x_data1 =  [0, 1, 2, 3, 4, 5]
y_data1 = [2, 4, 9, 5, 1, 8]

# %%
#折れ線グラフ
plt.plot(x_data1, y_data1, color="r")

# %%
# x軸のarrayとy軸のarrayに数値を格納
x_data2 = np.array([1, 2, 3, 4, 5])
y_data2 = np.array([12, 14, 15, 9, 8])

# %%
# 棒グラフ
plt.bar(x_data2, y_data2)
# Out:
# <BarContainer object of 5 artists>

# %%
#-5から5まで0.1の増え幅で配列を作る
x_data3 = np.arange(0, 2*3.14, 0.1)

# %%
# sin(x)をyのlist格納して生成
y_data3 = np.sin(x_data3)

# %%
# sinカーブの描画
plt.plot(x_data3, y_data3)

# %% [markdown]
# 補足プログラム

# %%
#グラフタイトルの追加
plt.title('sine wave')

#x軸とy軸ラベルの追加
plt.xlabel('X')
plt.ylabel('Y')

# 赤色に変更（r=red）
plt.plot(x_data3, y_data3, color='r')

# %%
# 空のサブプロットを作成
# fig = Figure:描画領域全体, ax = Axes:一つのプロットを描画する領域
fig, axes= plt.subplots(2,2,figsize=(15,10))   # axesはAxesオブジェクトの2x2の配列

# サブプロットにタイトル追加
axes[0,0].set_title("subplot_0")
axes[0,1].set_title("subplot_1")
axes[1,0].set_title("subplot_2")
axes[1,1].set_title("subplot_3")
 
# サブプロットに軸ラベル追加
axes[0,0].set_xlabel("x0-label")
axes[0,0].set_ylabel("y0-label")
axes[0,1].set_xlabel("x1-label")
axes[0,1].set_ylabel("y1-label")
axes[1,0].set_xlabel("x2-label")
axes[1,0].set_ylabel("y2-label")
axes[1,1].set_xlabel("x3-label")
axes[1,1].set_ylabel("y3-label")

# 上記4つのグラフを描画
axes[0,0].plot(x,y)
axes[0,1].plot(x_data1,y_data1)
axes[1,0].plot(x_data2,y_data2)
axes[1,1].plot(x_data3,y_data3)
