# %%
import pandas as pd

# グラフ描画ライブラリ matplotlibのpyplotを plt という名前でimport
import matplotlib.pyplot as plt

#Jupyter Notebookの場合は、描画グラフをブラウザ内に表示するために inline指定
# %matplotlib inline

# %%
tochigi_population = pd.Series([515201,166643,141609,114846,114302],index=['Utsunomiya','Oyama','Ashikaga','Nasusiobara','Sano'])

tochigi_population
# Out:
# Utsunomiya     515201
# Oyama          166643
# Ashikaga       141609
# Nasusiobara    114846
# Sano           114302
# dtype: int64

# %%
tochigi_population.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('data_sample.csv', names=("Data", "Utsumomiya", "Sano", "Oyama", "Kuroiso"),encoding='utf8')

df
# Out:
#          Data  Utsumomiya  Sano  Oyama  Kuroiso
# 0   2022/8/14        27.7  27.9   27.6     25.9
# 1   2022/8/15        28.3  28.9   28.5     25.3
# 2   2022/8/16        29.8  30.9   30.2     26.2
# 3   2022/8/17        25.9  26.8   26.9     23.3
# 4   2022/8/18        24.5  25.3   24.6     22.4
# 5   2022/8/19        26.3  26.9   26.4     24.4
# 6   2022/8/20        24.8  25.4   25.1     22.4
# 7   2022/8/21        26.0  26.6   26.3     24.4
# 8   2022/8/22        26.4  27.2   26.3     24.4
# 9   2022/8/23        27.4  28.5   27.9     24.9
# 10  2022/8/24        27.1  28.0   27.4     23.7
# 11  2022/8/25        25.1  26.2   25.4     22.3
# 12  2022/8/26        25.7  27.2   25.9     23.7
# 13  2022/8/27        27.0  29.0   27.7     24.6
# 14  2022/8/28        22.3  23.3   22.6     19.8
# 15  2022/8/29        22.4  23.4   22.7     19.6
# 16  2022/8/30        21.7  22.5   21.8     19.9
# 17  2022/8/31        25.1  25.5   25.3     23.0
# 18   2022/9/1        26.5  26.4   26.2     24.8
# ...

# %%
df.plot(title="Average Temperature", figsize=(10,5), x='Data')
# Out:
# <AxesSubplot:title={'center':'Average Temperature'}, xlabel='Data'>

# %%
fig, ax = plt.subplots()

df.plot(ax=ax, title="Average Temperature", figsize=(10,5), x='Data')
ax.set_xlabel("Data")
ax.set_ylabel("Temperature[℃]")
# Out:
# Text(0, 0.5, 'Temperature[℃]')
